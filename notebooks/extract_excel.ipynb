# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent / "src"))   # so Python finds your modules in src/

import pandas as pd
#from presentation import write_presentation_excel

from presentation import write_presentation_excel

ROOT = Path.cwd().parent
df = pd.read_csv(ROOT / "data" / "consolidated" / "all_consolidated.csv")

# %% [raw]
# # Write the workbook. subscale_orders is optional; use it to fix column order.
# write_presentation_excel(
#     df,
#     ROOT / "data" / "output_excel.xlsx",
#     subscale_orders={"CTQ_SF": ["EA", "EN", "PA", "PN", "SA", "MD"]},
# )

# %%
write_presentation_excel(
    df, ROOT / "data" / "output_excel.xlsx",
    subscale_orders={"CTQ_SF": ["EA", "EN", "PA", "PN", "SA", "MD"]},
    ambiguous_publications=["Favrod et al. 2012", "Woodward et al. 2014", "Haddock et al. 1999"],
)
